# %% [markdown]
# ## Great, now that we discussed a little let's continue

# %% [markdown]
# Given that the current approach utilized by the authors lacks reproducibility, we will explore an alternative method by leveraging nf-core pipelines for data analysis.
#
# Please explain, how we will achieve reproducibility for the course  with this approach.

# %% [markdown]
# By using nf-core workflows, the exact parameters, versions etc. used for analysis can be more easily reproduced.

# %% [markdown]
# You have successfully downloaded 2 of the fastq files we will use in our study.
#
# What is the next step if we want to first have a count table and check the quality of our fastq files? What is the pipeline called to do so?

# %% [markdown]
# https://nf-co.re/rnaseq/3.21.0/ pipeline
# - qc
# - adapter trim
# - alignment to reference
# - transcript abundance estimation

# %% [markdown]
# Analyze the 2 files using an nf-core pipeline.
#
# What does this pipeline do?
#
# Which are the main tools that will be used in the pipeline?

# %% [markdown]
# The pipeline processes sequencing data, performs quality control and pre-processing, then performs alignment and transcript quantification, and does final post-processing/QC and exploratory analyis.
# - Salmon: Strand Inference
# - FastQC: Initial QC
# - TrimGalore: Adapter trim
# - STAR: Alignment to reference
# - Salmon: Transcript quantification (on reads?)
# - picard: Duplicate marking
# - StringTie: Transcript quantification (on contigs?)
# - DESeq2: Exploratory Analysis (PCA)
# - Qualimap/Kraken2 etc: Post-processing ?
# - MultiQC: Final QC on all files

# %% [markdown]
# As all other nf-core pipelines, the chosen pipeline takes in a samplesheet as input.
#
# Use Python and pandas to create the samplesheet for your 2 samples. Feel free to make use of the table you created earlier today.
#
# Choose your sample names wisely, they must be the connection of the results to the metadata. If you can't find the sample in the metadata later, the analysis was useless.

# %%
# post here the command you used to run nf-core/rnaseq
# !nextflow run nf-core/rnaseq --input ./fastq/samplesheet/samplesheet.csv --outdir ./rnaseq --genome GRCm38 -profile docker -resume -c rnaseq.config
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/rnaseq` [fabulous_mcclintock] DSL2 - revision: 9738a2df42 [master]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/rnaseq 3.21.0
# ------------------------------------------------------
# Input/output options
#   input              : ./fastq/samplesheet/samplesheet.csv
#   outdir             : ./rnaseq
#
# Reference genome options
#   genome             : GRCm38
#   fasta              : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
#   gtf                : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.gtf
#   gene_bed           : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.bed
#   star_index         : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/STARIndex/
#
# UMI options
#   umi_discard_read   : 0
#
# Generic options
#   trace_report_suffix: 2025-09-30_14-48-15
#
# Core Nextflow options
#   revision           : master
#   runName            : fabulous_mcclintock
#   containerEngine    : docker
#   launchDir          : /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02
#   workDir            : /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/work
#   projectDir         : /home/marcelullose/.nextflow/assets/nf-core/rnaseq
#   userName           : marcelullose
#   profile            : docker
#   configFiles        : /home/marcelullose/.nextflow/assets/nf-core/rnaseq/nextflow.config, /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/rnaseq.config
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# * The pipeline
#     https://doi.org/10.5281/zenodo.1400710
#
# * The nf-core framework
#     https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#     https://github.com/nf-core/rnaseq/blob/master/CITATIONS.md
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 4 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 9 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 14 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 27 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# executor >  local (1)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [17/59993a] NFC…ALORE:FASTQC (SRX19144486) | 0 of 2
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# executor >  local (1)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [17/59993a] NFC…ALORE:FASTQC (SRX19144486) | 0 of 2
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# executor >  local (1)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [17/59993a] NFC…ALORE:FASTQC (SRX19144486) | 0 of 2
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# WARN: Found the following unidentified headers in /home/marcelullose/Documents/SoSe25/ComputationalWorkflows/computational-workflows-2025/notebooks/day_02/fastq/samplesheet/samplesheet.csv:
# 	- run_accession
# 	- experiment_accession
# 	- sample_accession
# 	- secondary_sample_accession
# 	- study_accession
# 	- secondary_study_accession
# 	- submission_accession
# 	- run_alias
# 	- experiment_alias
# 	- sample_alias
# 	- study_alias
# 	- library_layout
# 	- library_selection
# 	- library_source
# 	- library_strategy
# 	- library_name
# 	- instrument_model
# 	- instrument_platform
# 	- base_count
# 	- read_count
# 	- tax_id
# 	- scientific_name
# 	- sample_title
# 	- experiment_title
# 	- study_title
# 	- sample_description
# 	- fastq_md5
# 	- fastq_bytes
# 	- fastq_ftp
# 	- fastq_galaxy
# 	- fastq_aspera
#
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [17/59993a] NFC…ALORE:FASTQC (SRX19144486) | 1 of 2
# [a8/d837e6] NFC…E:TRIMGALORE (SRX19144486) | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# executor >  local (3)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 1 of 2
# [a8/d837e6] NFC…E:TRIMGALORE (SRX19144486) | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# executor >  local (3)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 1 of 2
# [a8/d837e6] NFC…E:TRIMGALORE (SRX19144486) | 0 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
# executor >  local (3)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 1 of 2
# [a8/d837e6] NFC…E:TRIMGALORE (SRX19144486) | 1 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
# executor >  local (3)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 1 of 2
# [a8/d837e6] NFC…E:TRIMGALORE (SRX19144486) | 1 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING | 0 of 1
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
# executor >  local (4)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 2 of 2 ✔
# [7f/2f9162] NFC…E:TRIMGALORE (SRX19144488) | 1 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING | 0 of 1
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…
#
# executor >  local (4)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER | 0 of 1
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [95/cd0f16] NFC…NESS:FQ_LINT (SRX19144486) | 2 of 2, cached: 2 ✔
# [c2/76ee84] NFC…ALORE:FASTQC (SRX19144488) | 2 of 2 ✔
# [7f/2f9162] NFC…E:TRIMGALORE (SRX19144488) | 1 of 2
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING | 0 of 1
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 28 more processes waiting for tasks…

# %% [markdown]
# Explain all the parameters you set and why you set them in this way.

# %% [markdown]
# - `--input ./fastq/samplesheet/samplesheet.csv`: sample sheet as per previous SRA accession. Modified for functional file paths and added the strandedness information (as auto, to be infered by Salmon)
# - `--out_dir ./rnaseq`: output directory
# - `--genome GRCm38`: newest available mus musculus reference genome
# - `-resume`: In case of crashes
# - `-c rnaseq.config`: config file to use specified memory and threads

# %% [markdown]
# ## Browsing the results

# %% [markdown]
# How did the pipeline perform?

# %% [markdown]
# Explain the quality control steps. Are you happy with the quality and why. If not, why not.
# Please give additional information on :
# - ribosomal rRNA
# - Duplication
# - GC content
#
# What are the possible steps that could lead to poorer results?

# %% [markdown]
# Would you exclude any samples? If yes, which and why?

# %% [markdown]
# What would you now do to continue the experiment? What are the scientists trying to figure out? Which packages on R or python would you use?
